# %%
import rpy_parser as rpy
from rpy_parser import RaceData
from rpy_parser import CarData

# file_name = "rpy/3_player_replay.rpy"
file_name = "rpy/ACC_241002-210809_O_lamborghini_huracan_gt3_evo_nurburgring.rpy"
# file_name = "rpy/7213.rpy"
race_data = RaceData(file_name)
# Out:
# Found at position 5354

# %%
car = race_data._cars[0]

# %%
all_type = "<f"

# def cast(self):
#     cast_data = {
#         "coords": self._cast_vector3f(),
#         "arr1": self._cast_fixed_arr(8 if False else 2, all_type),
#         "contactPoint1": self._cast_vector3f(),
#         "contactPoint2": self._cast_vector3f(),
#         "contactPoint3": self._cast_vector3f(),
#         "contactPoint4": self._cast_vector3f(),
#         "unknown_1": self._cast_fixed_arr(1, all_type),
#         "maybe_steer_angle": self._cast_fixed_arr(1, all_type),
#         "arr2": self._cast_fixed_arr(7, all_type)
#     }
#     self._byte_counter.assert_start()
#     return cast_data
# 
# rpy.Packet104.cast = cast
# 
# def cast(self):
#     cast_data = {
#         "steer_angle": self._cast_fixed_arr(1, all_type)[0],
#         "brake": self._cast_fixed_arr(1, all_type),
#         "unknown": self._cast_fixed_arr(1, all_type),
#         "speed": self._cast_fixed_arr(1, all_type),
#         "arr3": self._cast_fixed_arr(8, all_type)
#         # "arr3": self._cast_fixed_arr(12, all_type)
#     }
#     self._byte_counter.assert_start()
#     return cast_data
# 
# rpy.Packet48.cast = cast
# 
# def cast(self):
#     cast_data = {
#         "arr4": self._cast_fixed_arr(18, all_type)
#     }
#     self._byte_counter.assert_start()
#     return cast_data
# 
# rpy.Packet72.cast = cast
# 
# def cast(self):
#     cast_data = {
#         "arr5": self._cast_fixed_arr(6, all_type)
#     }
#     self._byte_counter.assert_start()
#     return cast_data
# 
# rpy.Packet24.cast = cast
# 
# def cast(self):
#     cast_data = {
#         "arr6": self._cast_fixed_arr(4, all_type)
#     }
#     self._byte_counter.assert_start()
#     return cast_data
# 
# rpy.Packet16.cast = cast

# %%
# data = car.visualize(start_render=0.24, end_render=0.26)
data = car.visualize(start_render=0.2, end_render=1)
# Out:
# Merged 4463 dictionaries and added 2777 dictionaries
